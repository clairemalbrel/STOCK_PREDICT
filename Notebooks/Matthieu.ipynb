# %% [markdown]
# # DAY 1

# %%
import os
import json
import pandas as pd
import numpy as np
import gensim.models
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer, text_to_word_sequence
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ### Uploaded the 3 CSVs

# %%
path_reddit = r'C:\Users\henon\code\Stock_market\STOCK_PREDICT\data\RedditNews.csv'
path_news = r'C:\Users\henon\code\Stock_market\STOCK_PREDICT\data\Combined_News_DJIA.csv'
path_djia = r'C:\Users\henon\code\Stock_market\STOCK_PREDICT\data\upload_DJIA_table.csv'

# %%
reddit = pd.read_csv(path_reddit)
news = pd.read_csv(path_news)
djia = pd.read_csv(path_djia)

# %% [markdown]
# ### Merge Dataset

# %%
news['Date'] = pd.to_datetime(news['Date'])
djia['Date'] = pd.to_datetime(djia['Date'])
df = news.merge(djia)

# %%
df.shape
# Out:
# (1988, 37)

# %% [markdown]
# ### Sort out Y

# %%
# get percentage change
df['change'] = df['Open'].pct_change()

# %%
df['change'] = df['change'].shift(-1)

# %%
# Get categorical data
def categorical(x):
    if x > 0:
        x = 1
    else:
        x = 0
    return x

# %%
df['target'] = df['change'].apply(categorical)

# %%
# Combine the top 25 daily news into 1 column
cols = df.columns[2:]
df['combined'] = df[cols].apply(lambda row: '_'.join(row.values.astype(str)), axis=1)

# %%
df.head(3)
# Out:
#         Date  Label                                               Top1  \
# 1 2008-08-11      1  b'Why wont America and Nato help us? If they w...
# 2 2008-08-12      0  b'Remember that adorable 9-year-old who sang a...
# 3 2008-08-13      0  b' U.S. refuses Israel weapons to attack Iran:...
#
#                                                 Top2  \
# 1        b'Bush puts foot down on Georgian conflict'
# 2                 b"Russia 'ends Georgia operation'"
# 3  b"When the president ordered to attack Tskhinv...
#
#                                                 Top3  \
# 1  b"Jewish Georgian minister: Thanks to Israeli ...
# 2  b'"If we had no sexual harassment we would hav...
# 3  b' Israel clears troops who killed Reuters cam...
#
#                                                 Top4  \
# 1  b'Georgian army flees in disarray as Russians ...
# 2  b"Al-Qa'eda is losing support in Iraq because ...
# 3  b'Britain\'s policy of being tough on drugs is...
#
#                                                 Top5  \
# 1      b"Olympic opening ceremony fireworks 'faked'"
# 2  b'Ceasefire in Georgia: Putin Outmaneuvers the...
# 3  b'Body of 14 year old found in trunk; Latest (...
#
#                                                 Top6  \
# 1  b'What were the Mossad with fraudulent New Zea...
# 2  b'Why Microsoft and Intel tried to kill the XO...
# 3  b'China has moved 10 *million* quake survivors...
#
#                                                 Top7  \
# 1  b'Russia angered by Israeli military sale to G...
# 2  b'Stratfor: The Russo-Georgian War and the Bal...
# 3  b"Bush announces Operation Get All Up In Russi...
#
#                                                 Top8  ...          Open  \
# 1  b'An American citizen living in S.Ossetia blam...  ...  11729.669922
# 2  b"I'm Trying to Get a Sense of This Whole Geor...  ...  11781.700195
# 3             b'Russian forces sink Georgian ships '  ...  11632.809570
#
#            High           Low         Close     Volume     Adj Close  \
# 1  11867.110352  11675.530273  11782.349609  183190000  11782.349609
# 2  11782.349609  11601.519531  11642.469727  173590000  11642.469727
# 3  11633.780273  11453.339844  11532.959961  182550000  11532.959961
#
#      change target                                           combined  \
# 1  0.004436      1  b'Why wont America and Nato help us? If they w...
# 2 -0.012637      0  b'Remember that adorable 9-year-old who sang a...
# 3 -0.008660      0  b' U.S. refuses Israel weapons to attack Iran:...
#
#                                              cleaned
# 1  wont America Nato help u If wont help u help I...
# 2  adorable sang opening ceremony That fake Georg...
# 3  b refuse Israel weapon attack Iran president o...
#
# [3 rows x 37 columns]

# %% [markdown]
# ### Data Cleaning

# %%
from sklearn.preprocessing import FunctionTransformer
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords 
from nltk.stem import WordNetLemmatizer
import string
import re

# %%
def clean(text):
    punctuation = '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
    for punctuation in punctuation:
        review1 = text.replace(punctuation, ' ') # Remove Punctuation
    lowercased = text.lower() # Lower Case
    without_b=text.replace(" b ","")
    without_b=text.replace("b'","")
    without_b=text.replace('b"',"")
    tokenized = word_tokenize(without_b) # Tokenize
    words_only = [word for word in tokenized if word.isalpha()] # Remove numbers
    stop_words = set(stopwords.words('english')) # Make stopword list
    without_stopwords = [word for word in words_only if not word in stop_words] # Remove Stop Words
    lemma=WordNetLemmatizer() # Initiate Lemmatizer
    lemmatized = [lemma.lemmatize(word) for word in without_stopwords] # Lemmatize
    return " ".join(lemmatized)
df['cleaned'] = df['combined'].apply(clean)

# %%
df['cleaned'][3]
# Out:
# 'b refuse Israel weapon attack Iran president ordered attack Tskhinvali capital South Ossetia knew doomed How come realize Israel clear troop killed Reuters policy tough drug pointless say former civil servant ran unit year old found trunk Latest ransom paid kidnapping victim Mexico Head cop quits Prez dissolve suspect elite task moved million quake survivor prefab announces Operation Get All Up In Russia Grill Yeah end well force sink Georgian ship commander Navy air reconnaissance squadron provides President defense secretary airborne ability command nation nuclear weapon relieved duty CNN reader Russia action Georgia justified send fleet Black Sea help Georgia send troop humanitarian aid exercise warns Israeli plan strike Iran nuclear facility intriguing cyberalliance two Estonian computer expert heading Georgia keep country network running amid intense military confrontation Russia CNN Effect Georgia Schools Russia Information Russias response Georgia extinct humanitarian mission soon Georgia Russia hit US WWIII DDOS came US source convoy head Georgia violating defence minister US strike We Had No Russian force head towards Tbilisi breach ceasefire Quarter Russians blame conflict president say US military take control seaport airport Pentagon Nobel laureate Aleksander Solzhenitsyn accuses NATO encircling'

# %%
df.head(3)
# Out:
#         Date  Label                                               Top1  \
# 1 2008-08-11      1  b'Why wont America and Nato help us? If they w...
# 2 2008-08-12      0  b'Remember that adorable 9-year-old who sang a...
# 3 2008-08-13      0  b' U.S. refuses Israel weapons to attack Iran:...
#
#                                                 Top2  \
# 1        b'Bush puts foot down on Georgian conflict'
# 2                 b"Russia 'ends Georgia operation'"
# 3  b"When the president ordered to attack Tskhinv...
#
#                                                 Top3  \
# 1  b"Jewish Georgian minister: Thanks to Israeli ...
# 2  b'"If we had no sexual harassment we would hav...
# 3  b' Israel clears troops who killed Reuters cam...
#
#                                                 Top4  \
# 1  b'Georgian army flees in disarray as Russians ...
# 2  b"Al-Qa'eda is losing support in Iraq because ...
# 3  b'Britain\'s policy of being tough on drugs is...
#
#                                                 Top5  \
# 1      b"Olympic opening ceremony fireworks 'faked'"
# 2  b'Ceasefire in Georgia: Putin Outmaneuvers the...
# 3  b'Body of 14 year old found in trunk; Latest (...
#
#                                                 Top6  \
# 1  b'What were the Mossad with fraudulent New Zea...
# 2  b'Why Microsoft and Intel tried to kill the XO...
# 3  b'China has moved 10 *million* quake survivors...
#
#                                                 Top7  \
# 1  b'Russia angered by Israeli military sale to G...
# 2  b'Stratfor: The Russo-Georgian War and the Bal...
# 3  b"Bush announces Operation Get All Up In Russi...
#
#                                                 Top8  ...          Open  \
# 1  b'An American citizen living in S.Ossetia blam...  ...  11729.669922
# 2  b"I'm Trying to Get a Sense of This Whole Geor...  ...  11781.700195
# 3             b'Russian forces sink Georgian ships '  ...  11632.809570
#
#            High           Low         Close     Volume     Adj Close  \
# 1  11867.110352  11675.530273  11782.349609  183190000  11782.349609
# 2  11782.349609  11601.519531  11642.469727  173590000  11642.469727
# 3  11633.780273  11453.339844  11532.959961  182550000  11532.959961
#
#      change target                                           combined  \
# 1  0.004436      1  b'Why wont America and Nato help us? If they w...
# 2 -0.012637      0  b'Remember that adorable 9-year-old who sang a...
# 3 -0.008660      0  b' U.S. refuses Israel weapons to attack Iran:...
#
#                                              cleaned
# 1  wont America Nato help u If wont help u help I...
# 2  adorable sang opening ceremony That fake Georg...
# 3  b refuse Israel weapon attack Iran president o...
#
# [3 rows x 37 columns]

# %%
import re
if re.search(r'^b\s', text):
        text = text.replace("b ","")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-135-fb3e11650796> in <module>
#       1 import re
# ----> 2 if re.search(r'^b\s', text):
#       3         text = text.replace("b ","")
#
# ~\AppData\Local\Programs\Python\Python37\lib\re.py in search(pattern, string, flags)
#     181     """Scan through string looking for a match to the pattern, returning
#     182     a Match object, or None if no match was found."""
# --> 183     return _compile(pattern, flags).search(string)
#     184
#     185 def sub(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %% [markdown]
# ### Bag of Words

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()

X_bow = vectorizer.fit_transform(df.clean_text)

# %% [markdown]
# Some of the reviews in the dataset are too short to be considered for training. Others are too long.
#
# Keep only the reviews that are between 100 and 500 words.

# %%
def word_count(string):
    tokens = string.split()
    n_tokens = len(tokens)
    return n_tokens

df['count'] = df['cleaned'].apply(word_count)
df = df[(df['count'] > 100) & (df['count'] < 500)]

len(df) #useless cause no review with less than 100 words
# Out:
# 1988

# %% [markdown]
# ## Vectorizer tuning

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import GridSearchCV

pipeline = Pipeline([
    ('vectorizer', CountVectorizer()),
    ('nb', MultinomialNB())])

parameters = {'vectorizer__ngram_range': [(1, 1),(2,2)],
              'vectorizer__max_df':[0.33,0.5,0.75],
              'vectorizer__min_df':[0.05,0.1],
              'vectorizer__max_features' : [25,50,100],
              "nb__alpha":[0.1,0.5,1]}

gridsearch = GridSearchCV(pipeline, parameters, cv=5, scoring="accuracy")

gridsearch.fit(df.cleaned, df.Label)

print( "Best score:", gridsearch.best_score_)
# Out:
# Best score: 0.5301823981367797

# %%
print( "Best parameters:", gridsearch.best_params_)
# Out:
# Best parameters: {'nb__alpha': 0.1, 'vectorizer__max_df': 0.75, 'vectorizer__max_features': 25, 'vectorizer__min_df': 0.1, 'vectorizer__ngram_range': (1, 1)}

# %% [markdown]
# # DAY 2

# %%
import gensim
from gensim.test.utils import datapath
from gensim import utils

# %%
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split

X = df['cleaned']
y = df['Label']

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.3)

# %%
#Tokenize the cleaned column
from gensim.utils import tokenize
sentance = [list(tokenize(s, deacc=True, lower=True)) for s in df['cleaned']]

# %%
df['cleaned'][1]
# Out:
# 'wont America Nato help u If wont help u help Iraq put foot Georgian Georgian minister Thanks Israeli training fending Russia army flees disarray Russians advance Gori abandoned Russia without shot opening ceremony firework Mossad fraudulent New Zealand Passports Iraq angered Israeli military sale American citizen living blame Georgian leader genocide innocent To World War IV Now In High Definition move mistake monumental proportion press deeper Georgia say regime change Bindra win first ever Individual Olympic Gold Medal ship head Arctic define Jerusalem taxi station threaten quit rather work new bos French Team Stunned Phelps Relay US behind Georgian aggression Do believe TV neither Russian Georgian There much victim still going Montreal Canada police murdered boy Saturday overtake US largest South Ossetia PICS Physicians Group Condemns State Russia beaten United States head Peak question Georgia Russia conflict much better come trading sex food'

# %%
len(sentance)
# Out:
# 1988

# %%
sentance[1]
# Out:
# ['adorable',
#  'sang',
#  'opening',
#  'ceremony',
#  'that',
#  'fake',
#  'georgia',
#  'operation',
#  'if',
#  'sexual',
#  'harassment',
#  'would',
#  'child',
#  'losing',
#  'support',
#  'iraq',
#  'brutal',
#  'crackdown',
#  'activity',
#  'regard',
#  'including',
#  'woman',
#  'buying',
#  'cucumber',
#  'georgia',
#  'putin',
#  'outmaneuvers',
#  'microsoft',
#  'intel',
#  'tried',
#  'kill',
#  'xo',
#  'the',
#  'war',
#  'balance',
#  'power',
#  'trying',
#  'get',
#  'sense',
#  'this',
#  'whole',
#  'war',
#  'vote',
#  'up',
#  'if',
#  'you',
#  'think',
#  'georgia',
#  'started',
#  'it',
#  'or',
#  'down',
#  'if',
#  'think',
#  'russia',
#  'did',
#  'us',
#  'military',
#  'surprised',
#  'timing',
#  'swiftness',
#  'russian',
#  'military',
#  'move',
#  'south',
#  'ossetia',
#  'still',
#  'trying',
#  'sort',
#  'happened',
#  'us',
#  'defense',
#  'official',
#  'said',
#  'monday',
#  'beats',
#  'war',
#  'drum',
#  'iran',
#  'dumps',
#  'georgian',
#  'military',
#  'attacked',
#  'south',
#  'ossetian',
#  'capital',
#  'tskhinvali',
#  'multiple',
#  'rocket',
#  'launcher',
#  'designed',
#  'devastate',
#  'large',
#  'area',
#  'use',
#  'footage',
#  'tskhinvali',
#  'ruin',
#  'cover',
#  'georgian',
#  'report',
#  'video',
#  'war',
#  'olympics',
#  'opening',
#  'violates',
#  'ancient',
#  'tradition',
#  'truce',
#  'conflict',
#  'games',
#  'the',
#  'ioc',
#  'could',
#  'respond',
#  'taking',
#  'game',
#  'away',
#  'russia',
#  'pyramid',
#  'large',
#  'luxor',
#  'stacked',
#  'pyramid',
#  'tokyo',
#  'top',
#  'party',
#  'cities',
#  'troop',
#  'still',
#  'georgia',
#  'know',
#  'georgia',
#  'first',
#  'place',
#  'russias',
#  'response',
#  'georgia',
#  'accuses',
#  'making',
#  'serious',
#  'blunder',
#  'pursuing',
#  'interest',
#  'caucasus',
#  'georgia',
#  'nato',
#  'cold',
#  'war',
#  'adorable',
#  'led',
#  'country',
#  'war',
#  'based',
#  'evidence',
#  'that',
#  'fake',
#  'georgia',
#  'the',
#  'israeli',
#  'sign',
#  'point',
#  'us',
#  'encouraging',
#  'georgia',
#  'invade',
#  'south',
#  'ossetia',
#  'goddamnit',
#  'bush',
#  'king',
#  'argues',
#  'us',
#  'nato',
#  'behind',
#  'georgian',
#  'invasion',
#  'south',
#  'ossetia',
#  'misjudged',
#  'russian',
#  'resolve',
#  'the',
#  'new',
#  'mexico',
#  'news',
#  'extinction',
#  'man',
#  'climate']

# %%
class MyCorpus(object):
    """An interator that yields sentences (lists of str)."""

    def __iter__(self):
        for line in sentance:
            # assume there's one document per line, tokens separated by whitespace
            yield line
            
corpus = MyCorpus()

# %%
import gensim.models
from gensim.models import word2vec

model = gensim.models.Word2Vec(sentences=corpus)

# %%
print(model.wv.vocab)
# Out:
# {'wont': <gensim.models.keyedvectors.Vocab object at 0x0000019E8E065608>, 'america': <gensim.models.keyedvectors.Vocab object at 0x0000019E8DCDF888>, 'nato': <gensim.models.keyedvectors.Vocab object at 0x0000019E90027D48>, 'help': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002B4C8>, 'u': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002B508>, 'if': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002B548>, 'iraq': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002B588>, 'put': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002B5C8>, 'foot': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002B488>, 'georgian': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002B3C8>, 'minister': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002B608>, 'thanks': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002B648>, 'israeli': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002B688>, 'training': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002B6C8>, 'russia': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002B708>, 'army': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002B748>, 'flees': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002B788>, 'disarray': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002B7C8>, 'russians': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002B808>, 'advance': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002B848>, 'abandoned': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002B888>, 'without': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002B8C8>, 'shot': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002B908>, 'opening': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002B948>, 'ceremony': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002B988>, 'firework': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002B9C8>, 'mossad': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002BA08>, 'fraudulent': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002BA48>, 'new': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002BA88>, 'zealand': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002BAC8>, 'angered': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002BB08>, 'military': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002BB48>, 'sale': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002BB88>, 'american': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002BBC8>, 'citizen': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002BC08>, 'living': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002BC48>, 'blame': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002BC88>, 'leader': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002BCC8>, 'genocide': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002BD08>, 'innocent': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002BD48>, 'to': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002BD88>, 'world': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002BDC8>, 'war': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002BE08>, 'now': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002BE48>, 'in': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002BE88>, 'high': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002BEC8>, 'definition': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002BF08>, 'move': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002BF48>, 'mistake': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002BF88>, 'proportion': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002BFC8>, 'press': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002F048>, 'deeper': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002F088>, 'georgia': <gensim.models.keyedvectors.Vocab object at 0x0000019E9002F0C8>, 'say': <gensim.models.keyedvec ...

# %%
def compute_mean_embedding(l):
    """
    l: list of words
    """
    embeddings = []
    for word in l:
        if word in model.wv:
            embeddings.append(model.wv[word])
    embeddings = np.array(embeddings)
    mean_embedding = np.mean(embeddings, axis=0)
    return mean_embedding

# %%
mean_vectors = []
for line in sentance:
    mean_vec = compute_mean_embedding(line)
    if mean_vec.shape != (100,):
        mean_vec= np.zeros((100,))
    mean_vectors.append(mean_vec)
mean_vectors = np.array(mean_vectors)
print(mean_vectors)
# Out:
# [[ 5.3531483e-05 -4.0379940e-03  6.7571037e-02 ... -3.4014739e-03
#    3.4141240e-01  4.6203643e-01]
#  [-2.8661577e-02  2.9765695e-04  9.4799809e-02 ... -2.3518534e-02
#    3.4481561e-01  4.7990686e-01]
#  [-3.2467535e-03 -3.9034352e-02  4.4547621e-02 ... -8.3060965e-02
#    3.3611798e-01  4.0858021e-01]
#  ...
#  [ 3.2304373e-02 -2.0952314e-02  1.1159199e-01 ...  8.6210612e-03
#    3.1434247e-01  4.6406960e-01]
#  [ 7.1759395e-02 -3.0337464e-02  1.4530420e-01 ... -1.2696328e-02
#    2.7835840e-01  4.6353331e-01]
#  [ 8.0864467e-02 -1.2855265e-02  1.6154502e-01 ...  7.2128056e-03
#    2.6306781e-01  4.4236791e-01]]

# %% [markdown]
# # Approach with Train Test Split

# %% [markdown]
# ## Train Validation Split

# %%
from sklearn.model_selection import train_test_split

X = df['cleaned']
y = df['Label']

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.3)

# %% [markdown]
# ## Tokenization

# %%
from nltk import word_tokenize
import string

X_train_tokenized = []

for review in X_train:
    review_modified = ''.join([character for character in review if character not in string.punctuation])
    review_modified = ''.join([character for character in review_modified if not character.isdigit()])
    review_modified = review_modified.lower()
    X_train_tokenized.append(['<START>'] + word_tokenize(review_modified))

# %%
X_val_tokenized = []

for review in X_val:
    review_modified = ''.join([character for character in review if character not in string.punctuation])
    review_modified = ''.join([character for character in review_modified if not character.isdigit()])
    review_modified = review_modified.lower()
    X_val_tokenized.append(['<START>'] + word_tokenize(review_modified))

# %% [markdown]
# ## Rushing to a baseline with Word2Vec and mean computing

# %% [markdown]
# ### Training the Word2Vec model

# %%
class MyCorpus(object):
    """An interator that yields sentences (lists of str)."""

    def __iter__(self):
        for line in X_train_tokenized:
            # Assume there's one document per line, tokens separated by whitespace
            yield line
            
corpus = MyCorpus()

# Iterate !

# %%
import gensim.models
from gensim.models import word2vec

model = gensim.models.Word2Vec(sentences=corpus)

# %% [markdown]
# ### Compute Mean Embeddings

# %%
def compute_mean_embedding(l):
    """
    l: list of words
    """
    embedded_l = np.array([model.wv[word] for word in l if word in model.wv.vocab.keys()])
    return embedded_l.mean(axis = 0)

# %%
X_train_mean_vectors = [compute_mean_embedding(review) for review in X_train_tokenized]

X_train_mean_vectors = np.array(X_train_mean_vectors)

X_train_mean_vectors.shape
# Out:
# (1391, 100)

# %%
X_val_mean_vectors = [compute_mean_embedding(review) for review in X_val_tokenized]

X_val_mean_vectors = np.array(X_val_mean_vectors)

X_val_mean_vectors.shape
# Out:
# (597, 100)

# %% [markdown]
# ### Running a few classifiers as a baseline

# %%
# %%time

from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier

ovr_log = OneVsRestClassifier(LogisticRegression(max_iter = 200))

ovr_log.fit(X_train_mean_vectors, y_train)

print(ovr_log.score(X_val_mean_vectors, y_val))
# Out:
# 0.5527638190954773
# Wall time: 43 ms

# %%
# %%time

from sklearn.tree import DecisionTreeClassifier

decision_tree = DecisionTreeClassifier()

decision_tree.fit(X_train_mean_vectors, y_train)

print(decision_tree.score(X_val_mean_vectors, y_val))
# Out:
# 0.5309882747068677
# Wall time: 247 ms

# %%
# %%time

from sklearn.ensemble import RandomForestClassifier

random_forest = RandomForestClassifier()

random_forest.fit(X_train_mean_vectors, y_train)

print(random_forest.score(X_val_mean_vectors, y_val))
# Out:
# 0.5527638190954773
# Wall time: 926 ms

# %%
# %%time

from xgboost import XGBClassifier
xgboost_model = XGBClassifier()
xgboost_model.fit(X_train_mean_vectors, y_train)
print(xgboost_model.score(X_val_mean_vectors, y_val))
# Out:
# 0.5293132328308208
# Wall time: 3.13 s

# %% [markdown]
# # Approach with specific train/test

# %%
#Train data: 2008-08-08 to 2014-12-31
train_2 = df[(df['Date'] > '2008-08-08') & (df['Date'] <= '2014-12-31')]
X_train_2 = train_2['cleaned']
y_train_2 = train_2['Label']

#Test data: 2015-01-02 to 2016-07-01
test_2 = df[(df['Date'] > '2015-01-02') & (df['Date'] <= '2016-07-01')]
X_val_2 = test_2['cleaned']
y_val_2 = test_2['Label']

# %% [markdown]
# ### Tokenization

# %%
from nltk import word_tokenize
import string

X_train_2_tokenized = []

for review in X_train_2:
    review_modified = ''.join([character for character in review if character not in string.punctuation])
    review_modified = ''.join([character for character in review_modified if not character.isdigit()])
    review_modified = review_modified.lower()
    X_train_2_tokenized.append(['<START>'] + word_tokenize(review_modified))

# %%
X_val_2_tokenized = []

for review in X_val_2:
    review_modified = ''.join([character for character in review if character not in string.punctuation])
    review_modified = ''.join([character for character in review_modified if not character.isdigit()])
    review_modified = review_modified.lower()
    X_val_2_tokenized.append(['<START>'] + word_tokenize(review_modified))

# %% [markdown]
# ### Training the Word2Vec model

# %%
class MyCorpus(object):
    """An interator that yields sentences (lists of str)."""

    def __iter__(self):
        for line in X_train_2_tokenized:
            # Assume there's one document per line, tokens separated by whitespace
            yield line
            
corpus = MyCorpus()

# Iterate !

# %%
import gensim.models
from gensim.models import word2vec

model_2 = gensim.models.Word2Vec(sentences=corpus)

# %%
def compute_mean_embedding(l):
    """
    l: list of words
    """
    embedded_l_2 = np.array([model_2.wv[word] for word in l if word in model_2.wv.vocab.keys()])
    return embedded_l_2.mean(axis = 0)

# %%
X_train_2_mean_vectors = [compute_mean_embedding(review) for review in X_train_2_tokenized]

X_train_2_mean_vectors = np.array(X_train_2_mean_vectors)

X_train_2_mean_vectors.shape
# Out:
# (1610, 100)

# %%
X_val_2_mean_vectors = [compute_mean_embedding(review) for review in X_val_2_tokenized]

X_val_2_mean_vectors = np.array(X_val_2_mean_vectors)

X_val_2_mean_vectors.shape
# Out:
# (377, 100)

# %% [markdown]
# ### Running a few classifiers as a baseline

# %%
# %%time

from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier

ovr_log = OneVsRestClassifier(LogisticRegression(max_iter = 200))

ovr_log.fit(X_train_2_mean_vectors, y_train_2)

print(ovr_log.score(X_val_2_mean_vectors, y_val_2))
# Out:
# 0.506631299734748
# Wall time: 41 ms

# %%
# %%time

from sklearn.tree import DecisionTreeClassifier

decision_tree = DecisionTreeClassifier()

decision_tree.fit(X_train_2_mean_vectors, y_train_2)

print(decision_tree.score(X_val_2_mean_vectors, y_val_2))
# Out:
# 0.5013262599469496
# Wall time: 171 ms

# %%
# %%time

from sklearn.ensemble import RandomForestClassifier

random_forest = RandomForestClassifier()

random_forest.fit(X_train_2_mean_vectors, y_train_2)

print(random_forest.score(X_val_2_mean_vectors, y_val_2))
# Out:
# 0.47214854111405835
# Wall time: 1.11 s

# %%
# %%time

from xgboost import XGBClassifier
xgboost_model = XGBClassifier()
xgboost_model.fit(X_train_2_mean_vectors, y_train_2)
print(xgboost_model.score(X_val_2_mean_vectors, y_val_2))
# Out:
# 0.5013262599469496
# Wall time: 851 ms

# %% [markdown]
# ## Tpot

# %%
# install dependencies
# !pip install deap update_checker tqdm stopit joblib torch
# install xgboost optionally
# !pip install xgboost
# install tpot
# !pip install tpot
# Out:
# Collecting deap
#   ERROR: Command errored out with exit status 1:
#    command: 'c:\users\henon\.venvs\lewagon\scripts\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\henon\\AppData\\Local\\Temp\\pip-install-uuq36juy\\torch\\setup.py'"'"'; __file__='"'"'C:\\Users\\henon\\AppData\\Local\\Temp\\pip-install-uuq36juy\\torch\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\henon\AppData\Local\Temp\pip-wheel-4lk2ba61'
#        cwd: C:\Users\henon\AppData\Local\Temp\pip-install-uuq36juy\torch\
#   Complete output (30 lines):
#   running bdist_wheel
#   running build
#   running build_deps
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\henon\AppData\Local\Temp\pip-install-uuq36juy\torch\setup.py", line 265, in <module>
#       description="Tensors and Dynamic neural networks in Python with strong GPU acceleration",
#     File "c:\users\henon\.venvs\lewagon\lib\site-packages\setuptools\__init__.py", line 145, in setup
#       return distutils.core.setup(**attrs)
#     File "C:\Users\henon\AppData\Local\Programs\Python\Python37\lib\distutils\core.py", line 148, in setup
#       dist.run_commands()
#     File "C:\Users\henon\AppData\Local\Programs\Python\Python37\lib\distutils\dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "C:\Users\henon\AppData\Local\Programs\Python\Python37\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "c:\users\henon\.venvs\lewagon\lib\site-packages\wheel\bdist_wheel.py", line 223, in run
#       self.run_command('build')
#     File "C:\Users\henon\AppData\Local\Programs\Python\Python37\lib\distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\henon\AppData\Local\Programs\Python\Python37\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\henon\AppData\Local\Programs\Python\Python37\lib\distutils\command\build.py", line 135, in run
#       self.run_command(cmd_name)
#     File "C:\Users\henon\AppData\Local\Programs\Python\Python37\lib\distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\henon\AppData\Local\Programs\Python\Python37\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\henon\AppData\Local\Temp\pip-install-uuq36juy\torch\setup.py", line 51, in run
#       from tools.nnwrap import generate_wrappers as generate_nn_wrappers
#   ModuleNotFoundError: No module named 'tools.nnwrap'
#   ----------------------------------------
#   ERROR: Failed building wheel for torch
#   ERROR: Command errored out with exit status 1:
#    command: 'c:\users\henon\.venvs\lewagon\scripts\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\henon\\AppData\\Local\\Temp\\pip-install-uuq36juy\\torch\\setup.py'"'"'; __file__='"'"'C:\\Users\\henon\\AppData\\Local\\Temp\\pip-install-uuq36juy\\torch\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' clean --all
#        cwd: C:\Users\henon\AppData\Local\Temp\pip-install-uuq36juy\torch
#   Complete output (2 lines):
#   running clean
#   error: [Errno 2] No such file or directory: '.gitignore'
#   ----------------------------------------
#   ERROR: Failed cleaning build dir for torch
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\users\henon\.venvs\lewagon\scripts\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\henon\\AppData\\Local\\Temp\\pip-install-uuq36juy\\torch\\setup.py'"'"'; __file__='"'"'C:\\Users\\henon\\AppData\\Local\\Temp\\pip-install-uuq36juy\\torch\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\henon\AppData\Local\Temp\pip-record-o4xud55i\install-record.txt' --single-version-externally-managed --compile --install-headers 'c:\users\henon\.venvs\lewagon\include\site\python3.7\torch'
#          cwd: C:\Users\henon\AppData\Local\Temp\pip-install-uuq36juy\torch\
#     Complete output (23 lines):
#     running install
#     running build_deps
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\henon\AppData\Local\Temp\pip-install-uuq36juy\torch\setup.py", line 265, in <module>
#         description="Tensors and Dynamic neural networks in Python with strong GPU acceleration",
#       File "c:\users\henon\.venvs\lewagon\lib\site-packages\setuptools\__init__.py", line 145, in setup
#         return distutils.core.setup(**attrs)
#       File "C:\Users\henon\AppData\Local\Programs\Python\Python37\lib\distutils\core.py", line 148, in setup
#         dist.run_commands()
#       File "C:\Users\henon\AppData\Local\Programs\Python\Python37\lib\distutils\dist.py", line 966, in run_commands
#         self.run_command(cmd)
#       File "C:\Users\henon\AppData\Local\Programs\Python\Python37\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "C:\Users\henon\AppData\Local\Temp\pip-install-uuq36juy\torch\setup.py", line 99, in run
#         self.run_command('build_deps')
#       File "C:\Users\henon\AppData\Local\Programs\Python\Python37\lib\distutils\cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "C:\Users\henon\AppData\Local\Programs\Python\Python37\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "C:\Users\henon\AppData\Local\Temp\pip-install-uuq36juy\torch\setup.py", line 51, in run
#         from tools.nnwrap import generate_wrappers as generate_nn_wrappers
#     ModuleNotFoundError: No module named 'tools.nnwrap'
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'c:\users\henon\.venvs\lewagon\scripts\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\henon\\AppData\\Local\\Temp\\pip-install-uuq36juy\\torch\\setup.py'"'"'; __file__='"'"'C:\\Users\\henon\\AppData\\Local\\Temp\\pip-install-uuq36juy\\torch\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\henon\AppData\Local\Temp\pip-record-o4xud55i\install-record.txt' --single-version-externally-managed --compile --install-headers 'c:\users\henon\.venvs\lewagon\include\site\python3.7\torch' Check the logs for full command output.
#   Downloading deap-1.3.1-cp37-cp37m-win_amd64.whl (108 kB)
# Collecting update_checker
#   Downloading update_checker-0.17-py2.py3-none-any.whl (7.0 kB)
# Requirement already satisfied: tqdm in c:\users\henon\.venvs\lewagon\lib\site-packages (4.46.0)
# Collecting stopit
#   Downloading stopit-1.1.2.tar.gz (18 kB)
# Requirement already satisfied: joblib in c:\users\henon\.venvs\lewagon\lib\site-packages (0.14.1)
# Collecting torch
#   Downloading torch-0.1.2.post2.tar.gz (128 kB)
# Requirement already satisfied: numpy in c:\users\henon\.venvs\lewagon\lib\site-packages (from deap) (1.18.4)
# Requirement already satisfied: requests>=2.3.0 in c:\users\henon\.venvs\lewagon\lib\site-packages (from update_checker) (2.23.0)
# Requirement already satisfied: pyyaml in c:\users\henon\.venvs\lewagon\lib\site-packages (from torch) (5.3.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\henon\.venvs\lewagon\lib\site-packages (from requests>=2.3.0->update_checker) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\henon\.venvs\lewagon\lib\site-packages (from requests>=2.3.0->update_checker) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\henon\.venvs\lewagon\lib\site-packages (from requests>=2.3.0->update_checker) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\henon\.venvs\lewagon\lib\site-packages (from requests>=2.3.0->update_checker) (2020.4.5.1)
# Building wheels for collected packages: stopit, torch
#   Building wheel for stopit (setup.py): started
#   Building wheel for stopit (setup.py): finished with status 'done'
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11959 sha256=b18553dd671c615d011c207d7b81570e6d6d47d050bc7d11d3d0d928abe482c0
#   Stored in directory: c:\users\henon\appdata\local\pip\cache\wheels\e2\d2\79\eaf81edb391e27c87f51b8ef901ecc85a5363dc96b8b8d71e3
#   Building wheel for torch (setup.py): started
#   Building wheel for torch (setup.py): finished with status 'error'
#   Running setup.py clean for torch
# Successfully built stopit
# Failed to build torch
# Installing collected packages: deap, update-checker, stopit, torch
#     Running setup.py install for torch: started
#     Running setup.py install for torch: finished with status 'error'
# Requirement already satisfied: xgboost in c:\users\henon\.venvs\lewagon\lib\site-packages (1.1.1)
# Requirement already satisfied: scipy in c:\users\henon\.venvs\lewagon\lib\site-packages (from xgboost) (1.4.1)
# Requirement already satisfied: numpy in c:\users\henon\.venvs\lewagon\lib\site-packages (from xgboost) (1.18.4)
# Collecting tpot
#   Downloading TPOT-0.11.5-py3-none-any.whl (82 kB)
# Requirement already satisfied: update-checker>=0.16 in c:\users\henon\.venvs\lewagon\lib\site-packages (from tpot) (0.17)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\henon\.venvs\lewagon\lib\site-packages (from tpot) (1.18.4)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\henon\.venvs\lewagon\lib\site-packages (from tpot) (1.0.3)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\henon\.venvs\lewagon\lib\site-packages (from tpot) (0.14.1)
# Requirement already satisfied: scipy>=1.3.1 in c:\users\henon\.venvs\lewagon\lib\site-packages (from tpot) (1.4.1)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\henon\.venvs\lewagon\lib\site-packages (from tpot) (4.46.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\henon\.venvs\lewagon\lib\site-packages (from tpot) (0.23.1)
# Requirement already satisfied: stopit>=1.1.1 in c:\users\henon\.venvs\lewagon\lib\site-packages (from tpot) (1.1.2)
# Requirement already satisfied: deap>=1.2 in c:\users\henon\.venvs\lewagon\lib\site-packages (from tpot) (1.3.1)
# Requirement already satisfied: requests>=2.3.0 in c:\users\henon\.venvs\lewagon\lib\site-packages (from update-checker>=0.16->tpot) (2.23.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\henon\.venvs\lewagon\lib\site-packages (from pandas>=0.24.2->tpot) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\henon\.venvs\lewagon\lib\site-packages (from pandas>=0.24.2->tpot) (2020.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\henon\.venvs\lewagon\lib\site-packages (from scikit-learn>=0.22.0->tpot) (2.0.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\henon\.venvs\lewagon\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\henon\.venvs\lewagon\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\henon\.venvs\lewagon\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\henon\.venvs\lewagon\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2020.4.5.1)
# Requirement already satisfied: six>=1.5 in c:\users\henon\.venvs\lewagon\lib\site-packages (from python-dateutil>=2.6.1->pandas>=0.24.2->tpot) (1.14.0)
# Installing collected packages: tpot
# Successfully installed tpot-0.11.5

# %%
from sklearn.model_selection import train_test_split

X = df['cleaned']
y = df['Label']

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.3)

# %%
X
# Out:
# 1       wont America Nato help u If wont help u help I...
# 2       adorable sang opening ceremony That fake Georg...
# 3       b refuse Israel weapon attack Iran president o...
# 4       expert admit legalise drug South Osetia pictur...
# 5       Mom missing gay man Too bad cheerleader still ...
#                               ...
# 1984    Barclays RBS share suspended trading tanking s...
# 1985    Scientists To Australia If You Want To Save Th...
# 1986    Explosion At Airport In former president Terro...
# 1987    Jamaica proposes marijuana dispenser tourist a...
# 1988    A woman Mexico City finally received birth cer...
# Name: cleaned, Length: 1988, dtype: object

# %%
y
# Out:
# 1       1
# 2       0
# 3       0
# 4       1
# 5       1
#        ..
# 1984    0
# 1985    1
# 1986    1
# 1987    1
# 1988    1
# Name: Label, Length: 1988, dtype: int64

# %%
from sklearn.model_selection import train_test_split
import os
from tpot import TPOTClassifier

# instanciate TPOTClassifier
tpot = TPOTClassifier(config='TPOT text', generations=5, population_size=50, verbosity=2)
# process autoML with TPOT
tpot.fit(X_train, y_train)
# print score
print(tpot.score(X_val, y_val))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-cb1aba26e281> in <module>
#       4
#       5 # instanciate TPOTClassifier
# ----> 6 tpot = TPOTClassifier(config='TPOT text', generations=5, population_size=50, verbosity=2)
#       7 # process autoML with TPOT
#       8 tpot.fit(X_train, y_train)
#
# TypeError: __init__() got an unexpected keyword argument 'config'
