# %% [markdown]
# # **Daily News for Stock Market Prediction**
#
#
#
#
#
# ### Break into Wall Street: How can we predit whether the Dow Jones Index will increase or decrease tomorrow?

# %% [markdown]
# # Let's dive into our data
#
# - **News**: Top 25 News of the day (<u>Source</u>: Reddit)
# - **Dow Jones Index**: Daily values of the opening, closing, high and low of the Dow Jones Index (<u>Source</u>: Yahoo Finance)
#
# Get a graph with day jones opening and link the highest and lowest change to extract of the news

# %%
from IPython.display import Image
path = r'C:\Users\henon\Pictures\Screenshots\test.png'
Image(filename=path,width=800, height=400)
# Out:
#   File "<ipython-input-11-277863c1bf34>", line 3
#     <Image(filename=path,width=800, height=400)>
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Des débuts difficiles...
#
# Our first approach -> LDA

# %% [markdown]
# # What went wrong

# %%
from IPython.display import Image
path = r'C:\Users\henon\Pictures\Screenshots\Solution_found.png'
Image(filename=path,width=800, height=400)
# Out:
#   File "<ipython-input-9-c6cb17b88485>", line 1
#     <from IPython.display import Image
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # The subjectivity / objectivity approach

# %% [markdown]
# # What we do

# %% [markdown]
# # Results of the model

# %% [markdown]
# # Demo - Limits

# %%
from IPython.display import Image
path = r'C:\Users\henon\Pictures\Screenshots\Finish.png'
Image(filename=path,width=800, height=400)
